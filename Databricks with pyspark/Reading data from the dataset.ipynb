# %%
spark

# %%
df =spark.read.format('csv').option("inferschema",True).option("header",True).load("/Volumes/workspace/default/sampledataset/market_reaction.csv")
print("This Table contains the rates of specific products and industries from 2020-2026")
df.show()
